# %% [markdown]
# <a href="https://colab.research.google.com/github/SiriratL/6420412008_DADS5001_Miniproject/blob/main/09_Plotly/Week9_PK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reference
# - https://pbpython.com/plotly-look.html
# - Description of Data: https://www.kaggle.com/crawford/80-cereals
# - http://seaborn.pydata.org/examples/index.html

# %%
# px.scatter()
# px.line()
# px.bar()
# px.histogram()
# px.box()
# px.violin()
# px.strip()

# %%
df2 = pd.read_csv('https://github.com/SiriratL/DADS5001Tools_Final/blob/7780ee4de89e8c6f425519c962f338b61ce6984f/salaries.csv')
print(df2.shape)
df2.head()

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('https://github.com/chris1610/pbpython/blob/master/data/cereal_data.csv?raw=True')

print(df.shape)
df.head()
# Out:
# (77, 17)
#                         name             mfr  type  calories  protein  fat  \
# 0                  100% Bran         Nabisco  Cold        70        4    1
# 1          100% Natural Bran     Quaker Oats  Cold       120        3    5
# 2                   All-Bran         Kellogs  Cold        70        4    1
# 3  All-Bran with Extra Fiber         Kellogs  Cold        50        4    0
# 4             Almond Delight  Ralston Purina  Cold       110        2    2
#
#    sodium  fiber  carbo  sugars  potass  vitamins shelf  weight  cups  rating  \
# 0     130   10.0    5.0       6     280        25   Top     1.0  0.33   68.40
# 1      15    2.0    8.0       8     135         0   Top     1.0  1.00   33.98
# 2     260    9.0    7.0       5     320        25   Top     1.0  0.33   59.43
# 3     140   14.0    8.0       0     330        25   Top     1.0  0.50   93.70
# 4     200    1.0   14.0       8      -1        25   Top     1.0  0.75   34.38
#
#    cereal
# 0       1
# 1       1
# ...

# %%
df[(df.mfr=='Kellogs') & (df.shelf=='Top')].shelf.count()
# Out:
# 12

# %%
fig = px.scatter(df,
                x='sugars',
                y='rating',
                hover_name='name',
                title='Cereal ratings vs. sugars')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# A strip plot is very simple to understand. It is basically a scatter plot that differentiates different categories. 
# So, all the data that corresponds to each category is shown as a scatter plot, and all the observations and collected data that are visualized are shown, side-by-side on a single graph.
# better ถ้า เกิด diff category but same value, scatter มันจะ plot จุดเดียวกัน ทำให้ distort

fig = px.strip(df,
                x='sugars',
                y='calories',
                hover_name='name',
                title='Cereal ratings vs. sugars')
fig.show()

# ที่ sugar 3 มัน calories เดียวกัน แต่ต่าง brand ถ้า scatter มันจะ plot ทับเลย แต่ strip ไม่ทับ ... ดีกว่า
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, 
                   x='sugars', 
                   title='Rating distribution',
                   nbins=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df,
                x='sugars',
                y='rating',
                color='mfr',
                size='calories',
                facet_row='shelf',
                facet_col='type',
                hover_name='name',
                category_orders={'shelf': ['Top', 'Middle', 'Bottom']})
# facet row = แต่ละ row คือ shelf = top, middle, bottom
# facet column = แต่ละ column คือ type = cold, hot
# category_orders = เรียงตาม top, middle, bottom
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(
                 df, 
                 path=['shelf', 'mfr','name'], 
                 values='cereal', 
                 title='Cereals by shelf location'
                )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.sunburst(df, 
                  path=['mfr','shelf','type'], 
                  values='cereal')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.sunburst(df, 
                  path=['mfr','name'], 
                  values='calories')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# px.line()
# px.bar()
# px.box()
# px.violin()

# %%
px.line(df, x="name", y="sodium", title='calories')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df, x="mfr", y="calories", title='calories')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(df, x="mfr", y="calories", title='calories')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.violin(df, x="mfr", y="calories", title='calories')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = px.data.gapminder().query("country=='Canada'")
fig = px.line(df, x="year", y="lifeExp", title='Life expectancy in Canada')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-22cde07587ef> in <module>
# ----> 1 df = px.df().query("mfr=='Kellogs'")
#       2 fig = px.line(df, x="name", y="calories", title='test')
#       3 fig.show()
#
# AttributeError: module 'plotly.express' has no attribute 'df'

# %%
df = px.df().query("mfr=='Kellogs'")
fig = px.line(df, x="name", y="calories", title='test')
fig.show()

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/SiriratL/DADS5001Tools_Final/main/salaries.csv')
print(df2.shape)
display(df2.info())
df2#.head()
# Out:
# (1332, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           1332 non-null   int64
#  1   experience_level    1332 non-null   object
#  2   employment_type     1332 non-null   object
#  3   job_title           1332 non-null   object
#  4   salary              1332 non-null   int64
#  5   salary_currency     1332 non-null   object
#  6   salary_in_usd       1332 non-null   int64
#  7   employee_residence  1332 non-null   object
#  8   remote_ratio        1332 non-null   int64
#  9   company_location    1332 non-null   object
#  10  company_size        1332 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 114.6+ KB
# None
#       work_year experience_level employment_type                  job_title  \
# 0          2022               MI              FT  Machine Learning Engineer
# ...

# %% [markdown]
# EN: Entry-level / Junior
# MI: Mid-level / Intermediate
# SE: Senior-level / Expert
# EX: Executive-level / Director

# %%
display(px.box(df2, x="job_title", y="salary_in_usd", title='salary_in_usd'))
display(px.box(df2, x="employment_type", y="salary_in_usd", title='salary_in_usd'))
display(px.box(df2, x="experience_level", y="salary_in_usd", title='salary_in_usd'))
display(px.box(df2, x="company_size", y="salary_in_usd", title='salary_in_usd'))
display(px.box(df2, x="employee_residence", y="salary_in_usd", title='salary_in_usd'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dfth = df2[(df2.employee_residence=='TH')]
dfth
# Out:
#      work_year experience_level employment_type                   job_title  \
# 401       2021               EN              FT  Machine Learning Developer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 401   15000             USD          15000                 TH           100
#
#     company_location company_size
# 401               TH            L

# %%
fig = px.sunburst(df2, 
                  path=['company_size','company_location','job_title'], 
                  values='salary_in_usd')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.data#.gapminder()
# Out:
# <module 'plotly.express.data' from '/usr/local/lib/python3.7/dist-packages/plotly/express/data/__init__.py'>
